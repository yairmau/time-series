# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(style="ticks", font_scale=1.5)  # white graphs, with large and legible letters
# %matplotlib widget

# %%
filename = "../archive/data/2021-12-10_wind_10Hz_raw.csv"
df = pd.read_csv(filename)
df['date'] = pd.to_datetime(df['TIMESTAMP'])
df = df.set_index('date')
df
# Out:
#                                        TIMESTAMP   RECORD    Wx    Wy    Wz  \
# date
# 2021-12-10 00:00:00.000  2021-12-10 00:00:00.000  7317433  1.61  1.09 -0.17
# 2021-12-10 00:00:00.100  2021-12-10 00:00:00.100  7317434  1.60  1.08 -0.16
# 2021-12-10 00:00:00.200  2021-12-10 00:00:00.200  7317435  1.58  1.08 -0.16
# 2021-12-10 00:00:00.300  2021-12-10 00:00:00.300  7317436  1.58  1.07 -0.17
# 2021-12-10 00:00:00.400  2021-12-10 00:00:00.400  7317437  1.57  1.06 -0.18
# ...                                          ...      ...   ...   ...   ...
# 2021-12-10 23:59:59.500  2021-12-10 23:59:59.500  8181428  1.21  0.32  0.03
# 2021-12-10 23:59:59.600  2021-12-10 23:59:59.600  8181429  1.21  0.32  0.03
# 2021-12-10 23:59:59.700  2021-12-10 23:59:59.700  8181430  1.21  0.32  0.03
# 2021-12-10 23:59:59.800  2021-12-10 23:59:59.800  8181431  1.21  0.32  0.03
# 2021-12-10 23:59:59.900  2021-12-10 23:59:59.900  8181432  1.21  0.32  0.03
#
#                            Wt ThStat ThCsum
# date
# 2021-12-10 00:00:00.000  15.8     0E     4C
# 2021-12-10 00:00:00.100  15.8     0E     4D
# 2021-12-10 00:00:00.200  15.8     0E     46
# 2021-12-10 00:00:00.300  15.8     0E     48
# 2021-12-10 00:00:00.400  15.8     0E     49
# ...                       ...    ...    ...
# 2021-12-10 23:59:59.500  19.9     0E     4F
# 2021-12-10 23:59:59.600  19.9     0E     4F
# 2021-12-10 23:59:59.700  19.9     0E     4F
# 2021-12-10 23:59:59.800  19.9     0E     4F
# 2021-12-10 23:59:59.900  19.9     0E     4F
#
# [864000 rows x 8 columns]

# %%
fig, ax = plt.subplots()
ax.plot(df['Wx'], color="tab:blue")
plt.gcf().autofmt_xdate()  # makes slanted dates
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
