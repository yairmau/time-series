# %%
import matplotlib.pyplot as plt

# Generate some random data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a plot
plt.plot(x, y)

# Add text at x = 0.5 (50% of figure width) and y = 5
plt.text(0.5, 5, 'Text', ha='center', va='center')

# Display the plot
plt.show()
